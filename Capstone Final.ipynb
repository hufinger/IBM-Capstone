# %%
# import libraries for webscraping
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
#Getting the Mecklenburg County (Charlotte area) zip codes
url = requests.get('https://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?ClientCode=capitolimpact&State=nc&StName=North%20Carolina&StFIPS=37&FIPS=37119').text
soup = BeautifulSoup(url, 'html.parser')
tables = soup.find_all('table', border = 3)
headings = ['ZipCode', 'City', 'County']
zips = []
for table in tables:

    rows = table.find_all('tr')

    zips.append([[td.getText().rstrip() for td in rows[i].findAll('td')]
    for i in range(len(rows))])

#remove the blank row from both lists
zip1 = zips[0][1:]
zip2 = zips[1][1:]


#make df for the zip codes
clt_zips = pd.DataFrame(zip1, columns = headings)
clt_zips = clt_zips.append(pd.DataFrame(zip2, columns = headings))

clt_zips['State'] = "NC"

# %%
#Repeat above steps for Orange Country (Chapel Hill area) zip codes
url = requests.get('http://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?ClientCode=capitolimpact&State=nc&StName=North%20Carolina&StFIPS=37&FIPS=37135').text
soup = BeautifulSoup(url, 'html.parser')
table = soup.find('table', border = 3)
headings = ['ZipCode', 'City', 'County']
rows = table.find_all('tr')

ch_zips = [[td.getText().rstrip() for td in rows[i].findAll('td')]
    for i in range(len(rows))]

#remove the blank row from the list
ch_zips = ch_zips[1:]


#make df for the zip codes
ch_zips = pd.DataFrame(ch_zips, columns = headings)

ch_zips['State'] = "NC"

# %%
#repeat for Nashville-Davidson County zip codes
url = requests.get('http://www.ciclt.net/sn/clt/capitolimpact/gw_ziplist.aspx?ClientCode=capitolimpact&State=tn&StName=Tennessee&StFIPS=47&FIPS=47037').text
soup = BeautifulSoup(url, 'html.parser')
table = soup.find('table', cellpadding = 3)
headings = ['ZipCode', 'City', 'County']
rows = table.find_all('tr')

tn_zips = [[td.getText().rstrip() for td in rows[i].findAll('td')]
    for i in range(len(rows))]

#remove the blank row from the list
tn_zips = tn_zips[1:]


#make df for the zip codes
tn_zips = pd.DataFrame(tn_zips, columns = headings)

tn_zips['State'] = "TN"

# %%
# combine all zip codes into one dataframe

all_zips = clt_zips
all_zips = all_zips.append(ch_zips)
all_zips = all_zips.append(tn_zips)

all_zips = all_zips.reset_index(drop = True)

#to verify print the unique counties (should be 3)
np.unique(all_zips.County)
# Out:
# array(['Davidson County', 'Mecklenburg County', 'Orange County'],
#       dtype=object)

# %%
#import geolocator packages
from geopy.geocoders import Nominatim

# %%
#joining lon - lat values to the dataframe
def get_coords(df):
    lat = []
    lon = []
    for i in range(len(df)):
        state = df.State[i]
        city = df.City[i]
        zipcode = df.ZipCode[i]
        address = city + ', '+ state + ' ' +zipcode
        geolocator = Nominatim(user_agent = 'my_explorer')
        location = geolocator.geocode(address)
        lat.append(location.latitude)
        lon.append(location.longitude)
    df['lat'] = lat
    df['lon'] = lon
    return df
final_zips = get_coords(all_zips)
final_zips
# Out:
#     ZipCode          City              County State        lat        lon
# 0     28031     Cornelius  Mecklenburg County    NC  35.481705 -80.859001
# 1     28035      Davidson  Mecklenburg County    NC  35.499261 -80.848522
# 2     28036      Davidson  Mecklenburg County    NC  35.499261 -80.848522
# 3     28070  Huntersville  Mecklenburg County    NC  35.410828 -80.842930
# 4     28078  Huntersville  Mecklenburg County    NC  35.410828 -80.842930
# ..      ...           ...                 ...   ...        ...        ...
# 128   37244     Nashville     Davidson County    TN  36.162230 -86.774353
# 129   37245     Nashville     Davidson County    TN  36.162230 -86.774353
# 130   37247     Nashville     Davidson County    TN  36.162230 -86.774353
# 131   37248     Nashville     Davidson County    TN  36.312392 -86.672015
# 132   37249     Nashville     Davidson County    TN  36.162230 -86.774353
#
# [133 rows x 6 columns]

# %%
#clean the data to remove duplicate lat/lon values
final_zips = final_zips.drop_duplicates(subset = ['lat', 'lon'])
print(final_zips.shape)
final_zips.head()
# Out:
# (36, 6)
#   ZipCode          City              County State        lat        lon
# 0   28031     Cornelius  Mecklenburg County    NC  35.481705 -80.859001
# 1   28035      Davidson  Mecklenburg County    NC  35.499261 -80.848522
# 3   28070  Huntersville  Mecklenburg County    NC  35.410828 -80.842930
# 5   28105      Matthews  Mecklenburg County    NC  35.115953 -80.722439
# 7   28126        Newell  Mecklenburg County    NC  35.279169 -80.736576

# %%
#import the map package from the earlier pieces of the capstone

# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=1976
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=1976
#   - conda-forge/linux-64::pytorch==1.8.0=cpu_py37hafa7651_0
# done
#
# # All requested packages already installed.

# %%
#split into the individual counties in order to create maps
nsh = final_zips[final_zips.County == 'Davidson County']
clt = final_zips[final_zips.County == 'Mecklenburg County']
ch = final_zips[final_zips.County == 'Orange County']

# %%
#Nashville Map
address = 'Nashville, TN'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_nashville = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, City, State in zip(nsh['lat'], nsh['lon'], nsh['City'], nsh['State']):
    label = '{}, {}'.format(City, State)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_nashville)  
map_nashville
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_094a4728f57342ff80bcf7faf12e731f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_094a4728f57342ff80bcf7faf12e731f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_094a4728f57342ff80bcf7faf12e731f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_094a4728f57342ff80bcf7faf12e731f%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B36.1622296%2C-86.7743531%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
#Charlotte Map
address = 'Charlotte, NC'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_charlotte = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, City, State in zip(clt['lat'], clt['lon'], clt['City'], clt['State']):
    label = '{}, {}'.format(City, State)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_charlotte)  
map_charlotte
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_ed48e598dbd54e6b8d86280211c4f371%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ed48e598dbd54e6b8d86280211c4f371%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ed48e598dbd54e6b8d86280211c4f371%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_ed48e598dbd54e6b8d86280211c4f371%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B35.2272086%2C-80.8430827%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
#Chapel Hill Map
address = 'Chapel Hill, NC'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_chapelhill = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, City, State in zip(ch['lat'], ch['lon'], ch['City'], ch['State']):
    label = '{}, {}'.format(City, State)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_chapelhill)  
map_chapelhill
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_05c7f9e7c9de42238e6e6a1529bc641c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_05c7f9e7c9de42238e6e6a1529bc641c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_05c7f9e7c9de42238e6e6a1529bc641c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_05c7f9e7c9de42238e6e6a1529bc641c%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B35.9131542%2C-79.05578%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
# @hidden_cell

CLIENT_ID = 'TGAOY3OUBXCTVPHFJHVNJ35B3WXIX33JRZTA0ZSXEZZWNG0A'
CLIENT_SECRET = 'RNBJLBMGO4QO4KZXG1F1SH0VAFYOQBUXX0UZ2GAGGZSIRURT'
CODE = 'OE53BZ210ZKEZVHQGKEBG1QMZZEPPJGQ052SYPFJVHWSBIC1#_=_'
ACCESS = 'XZO3PZAKY2VLQKVPLMNOZ3VA3YZU2SLWVKXQ5GBDLSVBXM3T'
VERSION = '20180605'

# %%
LIMIT = 100

def getNearbyVenues(names, latitudes, longitudes, radius=750):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
all_venues = getNearbyVenues(names = final_zips['City'],
                                 latitudes=final_zips['lat'],
                                   longitudes=final_zips['lon']
                                  )

all_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Cornelius              35.481705              -80.859001
# 1    Cornelius              35.481705              -80.859001
# 2    Cornelius              35.481705              -80.859001
# 3    Cornelius              35.481705              -80.859001
# 4    Cornelius              35.481705              -80.859001
#
#                         Venue  Venue Latitude  Venue Longitude  \
# 0       Old Town Public House       35.482148       -80.860568
# 1           SweetCakes Bakery       35.481886       -80.858196
# 2               crafty burg'r       35.481221       -80.855872
# 3  Parker Banner Kent & Wayne       35.480516       -80.858248
# 4             Fork Restaurant       35.487766       -80.858430
#
#             Venue Category
# 0                      Bar
# 1             Cupcake Shop
# 2  New American Restaurant
# 3               Hobby Shop
# 4               Restaurant

# %%
all_venues.groupby('Neighborhood').count()
# Out:
#                 Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Antioch                            10                      10     10
# Bellevue                            7                       7      7
# Carrboro                           49                      49     49
# Cedar Grove                         1                       1      1
# Chapel Hill                        70                      70     70
# Charlotte                         219                     219    219
# Cornelius                          19                      19     19
# Davidson                           28                      28     28
# Efland                              3                       3      3
# Goodlettsville                     58                      58     58
# Hermitage                           5                       5      5
# Hillsborough                       22                      22     22
# Huntersville                       13                      13     13
# Joelton                             4                       4      4
# Madison                            28                      28     28
# Matthews                           41                      41     41
# Melrose                            44                      44     44
# Mint Hill                          42                      42     42
# Nashville                         106                     106    106
# Newell                              3                       3      3
# Old Hickory                        15                      15     15
# Paw Creek                           4                       4      4
# Pineville                          23                      23     23
# Whites Creek                        7                       7      7
#
#                 Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Antioch                     10               10              10
# Bellevue                     7                7               7
# Carrboro                    49               49              49
# Cedar Grove                  1                1               1
# Chapel Hill                 70               70              70
# Charlotte                  219              219             219
# Cornelius                   19               19              19
# Davidson                    28               28              28
# Efland                       3                3               3
# Goodlettsville              58               58              58
# Hermitage                    5                5               5
# Hillsborough                22               22              22
# Huntersville                13               13              13
# Joelton                      4                4               4
# Madison                     28               28              28
# Matthews                    41               41              41
# Melrose                     44               44              44
# Mint Hill                   42               42              42
# Nashville                  106              106             106
# Newell                       3                3               3
# Old Hickory                 15               15              15
# Paw Creek                    4                4               4
# Pineville                   23               23              23
# Whites Creek                 7                7               7

# %%
print('There are {} uniques categories.'.format(len(all_venues['Venue Category'].unique())))
# Out:
# There are 210 uniques categories.

# %%
all_fixed = pd.get_dummies(all_venues[['Venue Category']], prefix = '', prefix_sep = '')

all_fixed['Neighbourhood'] = all_venues.Neighborhood

fixed_columns = [all_fixed.columns[-1]] + list(all_fixed.columns[:-1])
all_fixed = all_fixed[fixed_columns]

all_group = all_fixed.groupby('Neighbourhood').mean().reset_index()

all_group
# Out:
#      Neighbourhood       ATM  Accessories Store  American Restaurant  \
# 0          Antioch  0.000000           0.000000             0.000000
# 1         Bellevue  0.000000           0.000000             0.000000
# 2         Carrboro  0.000000           0.000000             0.040816
# 3      Cedar Grove  0.000000           0.000000             0.000000
# 4      Chapel Hill  0.000000           0.000000             0.042857
# 5        Charlotte  0.004566           0.000000             0.027397
# 6        Cornelius  0.000000           0.000000             0.052632
# 7         Davidson  0.000000           0.000000             0.107143
# 8           Efland  0.000000           0.000000             0.000000
# 9   Goodlettsville  0.017241           0.017241             0.017241
# 10       Hermitage  0.000000           0.000000             0.000000
# 11    Hillsborough  0.000000           0.000000             0.045455
# 12    Huntersville  0.000000           0.000000             0.076923
# 13         Joelton  0.000000           0.000000             0.000000
# 14         Madison  0.035714           0.000000             0.000000
# 15        Matthews  0.000000           0.000000             0.073171
# 16         Melrose  0.000000           0.000000             0.000000
# 17       Mint Hill  0.023810           0.000000             0.023810
# 18       Nashville  0.000000           0.000000             0.075472
# 19          Newell  0.000000           0.000000             0.000000
# 20     Old Hickory  0.000000           0.000000             0.000000
# 21       Paw Creek  0.000000           0.000000             0.000000
# 22       Pineville  0.000000           0.000000             0.000000
# 23    Whites Creek  0.000000           0.000000             0.000000
#
#     Antique Shop    Arcade  Art Gallery  Art Museum  Arts & Crafts Store  \
# 0       0.000000  0.000000     0.000000    0.000000             0.000000
# 1       0.000000  0.000000     0.000000    0.000000             0.000000
# 2       0.000000  0.000000     0.000000    0.000000             0.000000
# 3       0.000000  0.000000     0.000000    0.000000             0.000000
# 4       0.000000  0.000000     0.000000    0.014286             0.000000
# 5       0.000000  0.004566     0.004566    0.004566             0.000000
# 6       0.052632  0.000000     0.000000    0.000000             0.000000
# 7       0.000000  0.000000     0.000000    0.000000             0.000000
# 8       0.000000  0.000000     0.000000    0.000000             0.000000
# 9       0.000000  0.000000     0.000000    0.000000             0.000000
# 10      0.000000  0.000000     0.000000    0.000000             0.000000
# 11      0.000000  0.000000     0.000000    0.000000             0.045455
# 12      0.000000  0.000000     0.000000    0.000000             0.076923
# 13      0.000000  0.000000     0.000000    0.000000             0.000000
# 14      0.000000  0.000000     0.000000    0.000000             0.000000
# 15      0.000000  0.000000     0.000000    0.000000             0.000000
# 16      0.000000  0.000000     0.000000    0.000000             0.000000
# 17      0.000000  0.000000     0.000000    0.000000             0.000000
# 18      0.000000  0.000000     0.000000    0.000000             0.009434
# 19      0.000000  0.000000     0.000000    0.000000             0.000000
# 20      0.066667  0.000000     0.000000    0.000000             0.000000
# 21      0.000000  0.000000     0.000000    0.000000             0.000000
# 22      0.000000  0.000000     0.000000    0.000000             0.000000
# 23      0.000000  0.000000     0.000000    0.000000             0.000000
#
#     Asian Restaurant  ...  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0           0.000000  ...                       0.000000          0.000000
# 1           0.000000  ...                       0.000000          0.000000
# 2           0.000000  ...                       0.020408          0.000000
# 3           0.000000  ...                       0.000000          0.000000
# 4           0.014286  ...                       0.000000          0.014286
# 5           0.000000  ...                       0.000000          0.000000
# 6           0.000000  ...                       0.000000          0.000000
# 7           0.000000  ...                       0.000000          0.000000
# 8           0.000000  ...                       0.000000          0.000000
# 9           0.000000  ...                       0.000000          0.017241
# 10          0.000000  ...                       0.000000          0.000000
# 11          0.000000  ...                       0.000000          0.000000
# 12          0.000000  ...                       0.000000          0.000000
# 13          0.000000  ...                       0.000000          0.000000
# 14          0.000000  ...                       0.000000          0.000000
# 15          0.000000  ...                       0.000000          0.000000
# 16          0.000000  ...                       0.000000          0.000000
# 17          0.000000  ...                       0.000000          0.000000
# 18          0.000000  ...                       0.000000          0.000000
# 19          0.000000  ...                       0.000000          0.000000
# 20          0.000000  ...                       0.000000          0.000000
# 21          0.000000  ...                       0.000000          0.000000
# 22          0.043478  ...                       0.000000          0.000000
# 23          0.000000  ...                       0.000000          0.000000
#
#     Video Store  Vietnamese Restaurant  Whisky Bar  Wine Bar  Wine Shop  \
# 0      0.000000               0.000000    0.000000  0.000000   0.000000
# 1      0.000000               0.000000    0.000000  0.000000   0.000000
# 2      0.020408               0.000000    0.000000  0.020408   0.000000
# 3      0.000000               0.000000    0.000000  0.000000   0.000000
# 4      0.000000               0.000000    0.000000  0.000000   0.000000
# 5      0.000000               0.009132    0.000000  0.004566   0.004566
# 6      0.000000               0.000000    0.000000  0.000000   0.000000
# 7      0.000000               0.000000    0.000000  0.000000   0.000000
# 8      0.000000               0.000000    0.000000  0.000000   0.000000
# 9      0.017241               0.000000    0.000000  0.000000   0.000000
# 10     0.000000               0.000000    0.000000  0.000000   0.000000
# 11     0.000000               0.000000    0.000000  0.000000   0.045455
# 12     0.000000               0.000000    0.000000  0.000000   0.000000
# 13     0.000000               0.000000    0.000000  0.000000   0.000000
# 14     0.071429               0.000000    0.000000  0.000000   0.000000
# 15     0.024390               0.000000    0.000000  0.024390   0.000000
# 16     0.022727               0.000000    0.000000  0.000000   0.000000
# 17     0.000000               0.000000    0.000000  0.000000   0.000000
# 18     0.000000               0.000000    0.009434  0.000000   0.000000
# 19     0.000000               0.000000    0.000000  0.000000   0.000000
# 20     0.000000               0.000000    0.000000  0.000000   0.000000
# 21     0.000000               0.000000    0.000000  0.000000   0.000000
# 22     0.000000               0.000000    0.000000  0.000000   0.000000
# 23     0.000000               0.000000    0.000000  0.000000   0.000000
#
#     Wings Joint  Women's Store  Yoga Studio
# 0      0.000000       0.000000     0.000000
# 1      0.000000       0.000000     0.000000
# 2      0.020408       0.000000     0.020408
# 3      0.000000       0.000000     0.000000
# 4      0.014286       0.000000     0.014286
# 5      0.004566       0.000000     0.000000
# 6      0.000000       0.000000     0.000000
# 7      0.000000       0.000000     0.000000
# 8      0.000000       0.000000     0.000000
# 9      0.000000       0.017241     0.000000
# 10     0.000000       0.000000     0.000000
# 11     0.000000       0.000000     0.000000
# 12     0.000000       0.000000     0.000000
# 13     0.000000       0.000000     0.000000
# 14     0.000000       0.000000     0.000000
# 15     0.000000       0.000000     0.000000
# 16     0.000000       0.000000     0.000000
# 17     0.000000       0.000000     0.000000
# 18     0.000000       0.000000     0.000000
# 19     0.000000       0.000000     0.000000
# 20     0.000000       0.000000     0.000000
# 21     0.000000       0.000000     0.000000
# 22     0.000000       0.000000     0.000000
# 23     0.000000       0.000000     0.000000
#
# [24 rows x 211 columns]

# %%
for name in all_group.Neighbourhood:
    print('--------'+name+'-------')
    info = all_group[all_group.Neighbourhood == name].T.reset_index()
    info.columns = ['Venue', 'Freq']
    info = info.iloc[1:]
    info.Freq = info.Freq.astype(float)
    info = info.round({'Freq': 3})
    print(info.sort_values('Freq', ascending=False).reset_index(drop=True).head(3))
    print('\n')
# Out:
# --------Antioch-------
#                      Venue  Freq
# 0           Mattress Store   0.1
# 1  Comfort Food Restaurant   0.1
# 2             Soccer Field   0.1
#
#
# --------Bellevue-------
#                 Venue   Freq
# 0               Track  0.143
# 1  Light Rail Station  0.143
# 2              Bakery  0.143
#
#
# --------Carrboro-------
#          Venue   Freq
# 0  Pizza Place  0.082
# 1    Gift Shop  0.082
# 2  Coffee Shop  0.061
#
#
# --------Cedar Grove-------
#              Venue  Freq
# 0    Auto Workshop   1.0
# 1              ATM   0.0
# 2  Other Nightlife   0.0
#
#
# --------Chapel Hill-------
#                  Venue   Freq
# 0                  Bar  0.071
# 1       Sandwich Place  0.043
# 2  American Restaurant  0.043
#
#
# --------Charlotte-------
#          Venue   Freq
# 0  Pizza Place  0.059
# 1        Hotel  0.037
# 2  Coffee Shop  0.032
#
#
# --------Cornelius-------
#                     Venue   Freq
# 0             Supermarket  0.105
# 1          Cosmetics Shop  0.105
# 2  Furniture / Home Store  0.105
#
#
# --------Davidson-------
#                  Venue   Freq
# 0  American Restaurant  0.107
# 1   Mexican Restaurant  0.071
# 2       Ice Cream Shop  0.071
#
#
# --------Efland-------
#             Venue   Freq
# 0   Grocery Store  0.333
# 1    Burger Joint  0.333
# 2  Baseball Field  0.333
#
#
# --------Goodlettsville-------
#             Venue   Freq
# 0  Clothing Store  0.155
# 1      Shoe Store  0.069
# 2           Hotel  0.052
#
#
# --------Hermitage-------
#        Venue  Freq
# 0        Bar   0.2
# 1     Buffet   0.2
# 2  Pet Store   0.2
#
#
# --------Hillsborough-------
#                 Venue   Freq
# 0  Mexican Restaurant  0.136
# 1  Italian Restaurant  0.091
# 2        Dessert Shop  0.091
#
#
# --------Huntersville-------
#                 Venue   Freq
# 0  Italian Restaurant  0.154
# 1                 Pub  0.154
# 2         Pizza Place  0.154
#
#
# --------Joelton-------
#             Venue  Freq
# 0  Ice Cream Shop  0.25
# 1  Discount Store  0.25
# 2            Park  0.25
#
#
# --------Madison-------
#                   Venue   Freq
# 0  Fast Food Restaurant  0.107
# 1           Pizza Place  0.071
# 2           Video Store  0.071
#
#
# --------Matthews-------
#                  Venue   Freq
# 0  American Restaurant  0.073
# 1          Beer Garden  0.049
# 2          Pizza Place  0.049
#
#
# --------Melrose-------
#                   Venue   Freq
# 0  Fast Food Restaurant  0.068
# 1           Gas Station  0.045
# 2              Pharmacy  0.045
#
#
# --------Mint Hill-------
#          Venue   Freq
# 0  Pizza Place  0.143
# 1  Coffee Shop  0.071
# 2          Bar  0.071
#
#
# --------Nashville-------
#                  Venue   Freq
# 0                  Bar  0.142
# 1                Hotel  0.094
# 2  American Restaurant  0.075
#
#
# --------Newell-------
#                Venue   Freq
# 0     Rental Service  0.333
# 1  Convenience Store  0.333
# 2               Farm  0.333
#
#
# --------Old Hickory-------
#                Venue   Freq
# 0  Convenience Store  0.133
# 1               Food  0.067
# 2     Sandwich Place  0.067
#
#
# --------Paw Creek-------
#             Venue  Freq
# 0       Bookstore  0.25
# 1     Flower Shop  0.25
# 2  Rental Service  0.25
#
#
# --------Pineville-------
#               Venue   Freq
# 0            Bakery  0.087
# 1             Hotel  0.087
# 2  Toy / Game Store  0.087
#
#
# --------Whites Creek-------
#                              Venue   Freq
# 0                      Post Office  0.143
# 1  Southern / Soul Food Restaurant  0.143
# 2       Construction & Landscaping  0.143

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
x_ven = 8

indicators = ['st', 'nd', 'rd']


columns = ['Neighbourhood']
for ind in np.arange(x_ven):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = all_group['Neighbourhood']

for ind in np.arange(all_group.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(all_group.iloc[ind, :], x_ven)

neighborhoods_venues_sorted.head()
# Out:
#   Neighbourhood 1st Most Common Venue    2nd Most Common Venue  \
# 0       Antioch        Mattress Store  Comfort Food Restaurant
# 1      Bellevue                 Track       Light Rail Station
# 2      Carrboro           Pizza Place                Gift Shop
# 3   Cedar Grove         Auto Workshop                      ATM
# 4   Chapel Hill                   Bar           Sandwich Place
#
#   3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue  \
# 0          Soccer Field  Construction & Landscaping     Convenience Store
# 1                Bakery              Clothing Store           Gas Station
# 2           Coffee Shop                         Bar   American Restaurant
# 3       Other Nightlife   Middle Eastern Restaurant     Mobile Phone Shop
# 4   American Restaurant                     Brewery      Greek Restaurant
#
#   6th Most Common Venue 7th Most Common Venue            8th Most Common Venue
# 0                  Food     Mobile Phone Shop                    Moving Target
# 1          Intersection           Pizza Place                           Museum
# 2               Brewery                 Plaza  Southern / Soul Food Restaurant
# 3   Monument / Landmark         Movie Theater                    Moving Target
# 4    Mexican Restaurant           Pizza Place            Performing Arts Venue

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
k = 7

all_clusters = all_group.drop('Neighbourhood', axis = 1)

kmeans = KMeans(n_clusters=k, random_state=0).fit(all_clusters)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

all_merge = final_zips.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='City')

all_merge
# Out:
#     ZipCode            City              County State        lat        lon  \
# 0     28031       Cornelius  Mecklenburg County    NC  35.481705 -80.859001
# 1     28035        Davidson  Mecklenburg County    NC  35.499261 -80.848522
# 3     28070    Huntersville  Mecklenburg County    NC  35.410828 -80.842930
# 5     28105        Matthews  Mecklenburg County    NC  35.115953 -80.722439
# 7     28126          Newell  Mecklenburg County    NC  35.279169 -80.736576
# 8     28130       Paw Creek  Mecklenburg County    NC  35.266394 -80.914012
# 9     28134       Pineville  Mecklenburg County    NC  35.085541 -80.887125
# 10    28201       Charlotte  Mecklenburg County    NC  35.241229 -80.822664
# 11    28202       Charlotte  Mecklenburg County    NC  35.227209 -80.843083
# 14    28205       Charlotte  Mecklenburg County    NC  35.220475 -80.788593
# 20    28211       Charlotte  Mecklenburg County    NC  35.169402 -80.787483
# 21    28212       Charlotte  Mecklenburg County    NC  35.194865 -80.744604
# 22    28213       Charlotte  Mecklenburg County    NC  35.282136 -80.747809
# 32    28223       Charlotte  Mecklenburg County    NC  35.306230 -80.734491
# 36    28227       Charlotte  Mecklenburg County    NC  35.171692 -80.658838
# 37    28227       Mint Hill  Mecklenburg County    NC  35.173539 -80.657038
# 55    28262       Charlotte  Mecklenburg County    NC  35.320772 -80.746286
# 58    28269       Charlotte  Mecklenburg County    NC  35.329714 -80.803641
# 76    27231     Cedar Grove       Orange County    NC  36.167639 -79.167793
# 77    27243          Efland       Orange County    NC  36.081251 -79.169181
# 78    27278    Hillsborough       Orange County    NC  36.075230 -79.099228
# 79    27510        Carrboro       Orange County    NC  35.909987 -79.075288
# 80    27514     Chapel Hill       Orange County    NC  35.913154 -79.055780
# 84    37011         Antioch     Davidson County    TN  36.080639 -83.779904
# 85    37013         Antioch     Davidson County    TN  36.060060 -86.672219
# 86    37070  Goodlettsville     Davidson County    TN  36.305232 -86.705018
# 87    37072  Goodlettsville     Davidson County    TN  36.334912 -86.705339
# 88    37076       Hermitage     Davidson County    TN  36.189984 -86.605823
# 89    37080         Joelton     Davidson County    TN  36.313108 -86.865277
# 90    37115         Madison     Davidson County    TN  36.256165 -86.713886
# 92    37138     Old Hickory     Davidson County    TN  36.259713 -86.648088
# 93    37189    Whites Creek     Davidson County    TN  36.265887 -86.830832
# 94    37201       Nashville     Davidson County    TN  36.162230 -86.774353
# 97    37204         Melrose     Davidson County    TN  36.121851 -86.774760
# 115   37221        Bellevue     Davidson County    TN  36.064782 -86.939446
# 119   37227       Nashville     Davidson County    TN  36.312392 -86.672015
#
#      Cluster Labels 1st Most Common Venue            2nd Most Common Venue  \
# 0                 0           Supermarket                   Cosmetics Shop
# 1                 0   American Restaurant               Mexican Restaurant
# 3                 0    Italian Restaurant                              Pub
# 5                 0   American Restaurant                      Beer Garden
# 7                 2        Rental Service                Convenience Store
# 8                 6             Bookstore                      Flower Shop
# 9                 0                Bakery                            Hotel
# 10                0           Pizza Place                            Hotel
# 11                0           Pizza Place                            Hotel
# 14                0           Pizza Place                            Hotel
# 20                0           Pizza Place                            Hotel
# 21                0           Pizza Place                            Hotel
# 22                0           Pizza Place                            Hotel
# 32                0           Pizza Place                            Hotel
# 36                0           Pizza Place                            Hotel
# 37                0           Pizza Place                      Coffee Shop
# 55                0           Pizza Place                            Hotel
# 58                0           Pizza Place                            Hotel
# 76                1         Auto Workshop                              ATM
# 77                3         Grocery Store                     Burger Joint
# 78                0    Mexican Restaurant               Italian Restaurant
# 79                0           Pizza Place                        Gift Shop
# 80                0                   Bar                   Sandwich Place
# 84                0        Mattress Store          Comfort Food Restaurant
# 85                0        Mattress Store          Comfort Food Restaurant
# 86                0        Clothing Store                       Shoe Store
# 87                0        Clothing Store                       Shoe Store
# 88                5                   Bar                           Buffet
# 89                4        Ice Cream Shop                   Discount Store
# 90                0  Fast Food Restaurant                      Pizza Place
# 92                0     Convenience Store                             Food
# 93                0           Post Office  Southern / Soul Food Restaurant
# 94                0                   Bar                            Hotel
# 97                0  Fast Food Restaurant                      Gas Station
# 115               0                 Track               Light Rail Station
# 119               0                   Bar                            Hotel
#
#           3rd Most Common Venue          4th Most Common Venue  \
# 0        Furniture / Home Store                 Sandwich Place
# 1                Ice Cream Shop                           Café
# 3                   Pizza Place                    Coffee Shop
# 5                   Pizza Place                 Ice Cream Shop
# 7                          Farm                            ATM
# 8                Rental Service  Paper / Office Supplies Store
# 9              Toy / Game Store                  Jewelry Store
# 10                  Coffee Shop                     Restaurant
# 11                  Coffee Shop                     Restaurant
# 14                  Coffee Shop                     Restaurant
# 20                  Coffee Shop                     Restaurant
# 21                  Coffee Shop                     Restaurant
# 22                  Coffee Shop                     Restaurant
# 32                  Coffee Shop                     Restaurant
# 36                  Coffee Shop                     Restaurant
# 37                          Bar                 Ice Cream Shop
# 55                  Coffee Shop                     Restaurant
# 58                  Coffee Shop                     Restaurant
# 76              Other Nightlife      Middle Eastern Restaurant
# 77               Baseball Field                            ATM
# 78                 Dessert Shop                           Park
# 79                  Coffee Shop                            Bar
# 80          American Restaurant                        Brewery
# 84                 Soccer Field     Construction & Landscaping
# 85                 Soccer Field     Construction & Landscaping
# 86                        Hotel                     Kids Store
# 87                        Hotel                     Kids Store
# 88                    Pet Store                Automotive Shop
# 89                         Park                    Gas Station
# 90                  Video Store                 Discount Store
# 92               Sandwich Place                    Flea Market
# 93   Construction & Landscaping                           Food
# 94          American Restaurant                    Music Venue
# 97                     Pharmacy                   Liquor Store
# 115                      Bakery                 Clothing Store
# 119         American Restaurant                    Music Venue
#
#       5th Most Common Venue      6th Most Common Venue  \
# 0              Cupcake Shop    New American Restaurant
# 1                      Bank              Deli / Bodega
# 3                Print Shop        American Restaurant
# 5       Japanese Restaurant              Deli / Bodega
# 7            Nightlife Spot  Middle Eastern Restaurant
# 8                       ATM             Nightlife Spot
# 9                     Diner             Discount Store
# 10      American Restaurant                       Park
# 11      American Restaurant                       Park
# 14      American Restaurant                       Park
# 20      American Restaurant                       Park
# 21      American Restaurant                       Park
# 22      American Restaurant                       Park
# 32      American Restaurant                       Park
# 36      American Restaurant                       Park
# 37           Sandwich Place         Mexican Restaurant
# 55      American Restaurant                       Park
# 58      American Restaurant                       Park
# 76        Mobile Phone Shop        Monument / Landmark
# 77             Optical Shop          Mobile Phone Shop
# 78       Seafood Restaurant                Coffee Shop
# 79      American Restaurant                    Brewery
# 80         Greek Restaurant         Mexican Restaurant
# 84        Convenience Store                       Food
# 85        Convenience Store                       Food
# 86           Lingerie Store             Cosmetics Shop
# 87           Lingerie Store             Cosmetics Shop
# 88             Optical Shop                        ATM
# 89                      ATM               Optical Shop
# 90                      ATM                 Restaurant
# 92       Mexican Restaurant     Furniture / Home Store
# 93         Business Service             Clothing Store
# 94                     Park                 Steakhouse
# 97   Thrift / Vintage Store     Furniture / Home Store
# 115             Gas Station               Intersection
# 119                    Park                 Steakhouse
#
#          7th Most Common Venue            8th Most Common Venue
# 0                          Bar                       Restaurant
# 1                   Steakhouse                      Coffee Shop
# 3          Arts & Crafts Store                   Farmers Market
# 5                          Bar                        BBQ Joint
# 7            Mobile Phone Shop              Monument / Landmark
# 8    Middle Eastern Restaurant                Mobile Phone Shop
# 9                  Beer Garden                         Beer Bar
# 10                         Gym                   Sandwich Place
# 11                         Gym                   Sandwich Place
# 14                         Gym                   Sandwich Place
# 20                         Gym                   Sandwich Place
# 21                         Gym                   Sandwich Place
# 22                         Gym                   Sandwich Place
# 32                         Gym                   Sandwich Place
# 36                         Gym                   Sandwich Place
# 37        Fast Food Restaurant  Southern / Soul Food Restaurant
# 55                         Gym                   Sandwich Place
# 58                         Gym                   Sandwich Place
# 76               Movie Theater                    Moving Target
# 77         Monument / Landmark                    Movie Theater
# 78                   Gastropub                   Farmers Market
# 79                       Plaza  Southern / Soul Food Restaurant
# 80                 Pizza Place            Performing Arts Venue
# 84           Mobile Phone Shop                    Moving Target
# 85           Mobile Phone Shop                    Moving Target
# 86               Grocery Store                   Sandwich Place
# 87               Grocery Store                   Sandwich Place
# 88           Mobile Phone Shop              Monument / Landmark
# 89           Mobile Phone Shop              Monument / Landmark
# 90           Mobile Phone Shop             Caribbean Restaurant
# 92              Discount Store               Chinese Restaurant
# 93   Cajun / Creole Restaurant                              ATM
# 94                Cocktail Bar                      Pizza Place
# 97        Gym / Fitness Center               Chinese Restaurant
# 115                Pizza Place                           Museum
# 119               Cocktail Bar                      Pizza Place

# %%
#split into the individual counties in order to create maps
nsh = all_merge[all_merge.County == 'Davidson County']
clt = all_merge[all_merge.County == 'Mecklenburg County']
ch = all_merge[all_merge.County == 'Orange County']

# %%
# create map
address = 'Nashville, TN'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(all_merge['lat'], all_merge['lon'], all_merge['City'], all_merge['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_565e2811cf7943128c68259d57f9a8a5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_565e2811cf7943128c68259d57f9a8a5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_565e2811cf7943128c68259d57f9a8a5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_565e2811cf7943128c68259d57f9a8a5%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B36.1622296%2C-86.7743531%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# create map
address = 'Charlotte, NC'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(all_merge['lat'], all_merge['lon'], all_merge['City'], all_merge['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f23c7c5faa5b48de891a8279df69c95e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f23c7c5faa5b48de891a8279df69c95e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f23c7c5faa5b48de891a8279df69c95e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f23c7c5faa5b48de891a8279df69c95e%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B35.2272086%2C-80.8430827%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# create map
address = 'Chapel Hill, NC'
geolocator = Nominatim(user_agent = 'my_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(all_merge['lat'], all_merge['lon'], all_merge['City'], all_merge['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_5a535a3416a046129ce94a6d93527442%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5a535a3416a046129ce94a6d93527442%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5a535a3416a046129ce94a6d93527442%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_5a535a3416a046129ce94a6d93527442%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B35.9131542%2C-79.05578%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...

# %%
all_merge.loc[all_merge['Cluster Labels'] == 0, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#                City        lon  Cluster Labels 1st Most Common Venue  \
# 0         Cornelius -80.859001               0           Supermarket
# 1          Davidson -80.848522               0   American Restaurant
# 3      Huntersville -80.842930               0    Italian Restaurant
# 5          Matthews -80.722439               0   American Restaurant
# 9         Pineville -80.887125               0                Bakery
# 10        Charlotte -80.822664               0           Pizza Place
# 11        Charlotte -80.843083               0           Pizza Place
# 14        Charlotte -80.788593               0           Pizza Place
# 20        Charlotte -80.787483               0           Pizza Place
# 21        Charlotte -80.744604               0           Pizza Place
# 22        Charlotte -80.747809               0           Pizza Place
# 32        Charlotte -80.734491               0           Pizza Place
# 36        Charlotte -80.658838               0           Pizza Place
# 37        Mint Hill -80.657038               0           Pizza Place
# 55        Charlotte -80.746286               0           Pizza Place
# 58        Charlotte -80.803641               0           Pizza Place
# 78     Hillsborough -79.099228               0    Mexican Restaurant
# 79         Carrboro -79.075288               0           Pizza Place
# 80      Chapel Hill -79.055780               0                   Bar
# 84          Antioch -83.779904               0        Mattress Store
# 85          Antioch -86.672219               0        Mattress Store
# 86   Goodlettsville -86.705018               0        Clothing Store
# 87   Goodlettsville -86.705339               0        Clothing Store
# 90          Madison -86.713886               0  Fast Food Restaurant
# 92      Old Hickory -86.648088               0     Convenience Store
# 93     Whites Creek -86.830832               0           Post Office
# 94        Nashville -86.774353               0                   Bar
# 97          Melrose -86.774760               0  Fast Food Restaurant
# 115        Bellevue -86.939446               0                 Track
# 119       Nashville -86.672015               0                   Bar
#
#                2nd Most Common Venue       3rd Most Common Venue  \
# 0                     Cosmetics Shop      Furniture / Home Store
# 1                 Mexican Restaurant              Ice Cream Shop
# 3                                Pub                 Pizza Place
# 5                        Beer Garden                 Pizza Place
# 9                              Hotel            Toy / Game Store
# 10                             Hotel                 Coffee Shop
# 11                             Hotel                 Coffee Shop
# 14                             Hotel                 Coffee Shop
# 20                             Hotel                 Coffee Shop
# 21                             Hotel                 Coffee Shop
# 22                             Hotel                 Coffee Shop
# 32                             Hotel                 Coffee Shop
# 36                             Hotel                 Coffee Shop
# 37                       Coffee Shop                         Bar
# 55                             Hotel                 Coffee Shop
# 58                             Hotel                 Coffee Shop
# 78                Italian Restaurant                Dessert Shop
# 79                         Gift Shop                 Coffee Shop
# 80                    Sandwich Place         American Restaurant
# 84           Comfort Food Restaurant                Soccer Field
# 85           Comfort Food Restaurant                Soccer Field
# 86                        Shoe Store                       Hotel
# 87                        Shoe Store                       Hotel
# 90                       Pizza Place                 Video Store
# 92                              Food              Sandwich Place
# 93   Southern / Soul Food Restaurant  Construction & Landscaping
# 94                             Hotel         American Restaurant
# 97                       Gas Station                    Pharmacy
# 115               Light Rail Station                      Bakery
# 119                            Hotel         American Restaurant
#
#           4th Most Common Venue   5th Most Common Venue  \
# 0                Sandwich Place            Cupcake Shop
# 1                          Café                    Bank
# 3                   Coffee Shop              Print Shop
# 5                Ice Cream Shop     Japanese Restaurant
# 9                 Jewelry Store                   Diner
# 10                   Restaurant     American Restaurant
# 11                   Restaurant     American Restaurant
# 14                   Restaurant     American Restaurant
# 20                   Restaurant     American Restaurant
# 21                   Restaurant     American Restaurant
# 22                   Restaurant     American Restaurant
# 32                   Restaurant     American Restaurant
# 36                   Restaurant     American Restaurant
# 37               Ice Cream Shop          Sandwich Place
# 55                   Restaurant     American Restaurant
# 58                   Restaurant     American Restaurant
# 78                         Park      Seafood Restaurant
# 79                          Bar     American Restaurant
# 80                      Brewery        Greek Restaurant
# 84   Construction & Landscaping       Convenience Store
# 85   Construction & Landscaping       Convenience Store
# 86                   Kids Store          Lingerie Store
# 87                   Kids Store          Lingerie Store
# 90               Discount Store                     ATM
# 92                  Flea Market      Mexican Restaurant
# 93                         Food        Business Service
# 94                  Music Venue                    Park
# 97                 Liquor Store  Thrift / Vintage Store
# 115              Clothing Store             Gas Station
# 119                 Music Venue                    Park
#
#        6th Most Common Venue      7th Most Common Venue  \
# 0    New American Restaurant                        Bar
# 1              Deli / Bodega                 Steakhouse
# 3        American Restaurant        Arts & Crafts Store
# 5              Deli / Bodega                        Bar
# 9             Discount Store                Beer Garden
# 10                      Park                        Gym
# 11                      Park                        Gym
# 14                      Park                        Gym
# 20                      Park                        Gym
# 21                      Park                        Gym
# 22                      Park                        Gym
# 32                      Park                        Gym
# 36                      Park                        Gym
# 37        Mexican Restaurant       Fast Food Restaurant
# 55                      Park                        Gym
# 58                      Park                        Gym
# 78               Coffee Shop                  Gastropub
# 79                   Brewery                      Plaza
# 80        Mexican Restaurant                Pizza Place
# 84                      Food          Mobile Phone Shop
# 85                      Food          Mobile Phone Shop
# 86            Cosmetics Shop              Grocery Store
# 87            Cosmetics Shop              Grocery Store
# 90                Restaurant          Mobile Phone Shop
# 92    Furniture / Home Store             Discount Store
# 93            Clothing Store  Cajun / Creole Restaurant
# 94                Steakhouse               Cocktail Bar
# 97    Furniture / Home Store       Gym / Fitness Center
# 115             Intersection                Pizza Place
# 119               Steakhouse               Cocktail Bar
#
#                8th Most Common Venue
# 0                         Restaurant
# 1                        Coffee Shop
# 3                     Farmers Market
# 5                          BBQ Joint
# 9                           Beer Bar
# 10                    Sandwich Place
# 11                    Sandwich Place
# 14                    Sandwich Place
# 20                    Sandwich Place
# 21                    Sandwich Place
# 22                    Sandwich Place
# 32                    Sandwich Place
# 36                    Sandwich Place
# 37   Southern / Soul Food Restaurant
# 55                    Sandwich Place
# 58                    Sandwich Place
# 78                    Farmers Market
# 79   Southern / Soul Food Restaurant
# 80             Performing Arts Venue
# 84                     Moving Target
# 85                     Moving Target
# 86                    Sandwich Place
# 87                    Sandwich Place
# 90              Caribbean Restaurant
# 92                Chinese Restaurant
# 93                               ATM
# 94                       Pizza Place
# 97                Chinese Restaurant
# 115                           Museum
# 119                      Pizza Place

# %%
all_merge.loc[all_merge['Cluster Labels'] == 1, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#            City        lon  Cluster Labels 1st Most Common Venue  \
# 76  Cedar Grove -79.167793               1         Auto Workshop
#
#    2nd Most Common Venue 3rd Most Common Venue      4th Most Common Venue  \
# 76                   ATM       Other Nightlife  Middle Eastern Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 76     Mobile Phone Shop   Monument / Landmark         Movie Theater
#
#    8th Most Common Venue
# 76         Moving Target

# %%
all_merge.loc[all_merge['Cluster Labels'] == 2, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#      City        lon  Cluster Labels 1st Most Common Venue  \
# 7  Newell -80.736576               2        Rental Service
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 7     Convenience Store                  Farm                   ATM
#
#   5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 7        Nightlife Spot  Middle Eastern Restaurant     Mobile Phone Shop
#
#   8th Most Common Venue
# 7   Monument / Landmark

# %%
all_merge.loc[all_merge['Cluster Labels'] == 3, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#       City        lon  Cluster Labels 1st Most Common Venue  \
# 77  Efland -79.169181               3         Grocery Store
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 77          Burger Joint        Baseball Field                   ATM
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 77          Optical Shop     Mobile Phone Shop   Monument / Landmark
#
#    8th Most Common Venue
# 77         Movie Theater

# %%
all_merge.loc[all_merge['Cluster Labels'] == 4, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#        City        lon  Cluster Labels 1st Most Common Venue  \
# 89  Joelton -86.865277               4        Ice Cream Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 89        Discount Store                  Park           Gas Station
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 89                   ATM          Optical Shop     Mobile Phone Shop
#
#    8th Most Common Venue
# 89   Monument / Landmark

# %%
all_merge.loc[all_merge['Cluster Labels'] == 5, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#          City        lon  Cluster Labels 1st Most Common Venue  \
# 88  Hermitage -86.605823               5                   Bar
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 88                Buffet             Pet Store       Automotive Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 88          Optical Shop                   ATM     Mobile Phone Shop
#
#    8th Most Common Venue
# 88   Monument / Landmark

# %%
all_merge.loc[all_merge['Cluster Labels'] == 6, all_merge.columns[[1] + list(range(5, all_merge.shape[1]))]]
# Out:
#         City        lon  Cluster Labels 1st Most Common Venue  \
# 8  Paw Creek -80.914012               6             Bookstore
#
#   2nd Most Common Venue 3rd Most Common Venue          4th Most Common Venue  \
# 8           Flower Shop        Rental Service  Paper / Office Supplies Store
#
#   5th Most Common Venue 6th Most Common Venue      7th Most Common Venue  \
# 8                   ATM        Nightlife Spot  Middle Eastern Restaurant
#
#   8th Most Common Venue
# 8     Mobile Phone Shop
